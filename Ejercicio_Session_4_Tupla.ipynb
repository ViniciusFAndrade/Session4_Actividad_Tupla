# %%
#Crear la tupla
tupla = (10,20,30,40,50)

# %%
#Tipo de Tupla
type(tupla)
# Out:
# Out[39]: tuple

# %%
#Cambiar Tupla a Lista
lista = list(tupla)

# %%
#Tipo Lista
type(lista)
# Out:
# Out[41]: list

# %%
#Crear diccionário
keys = [1,2,3,4,5]
dic = dict.fromkeys(keys)

# %%
dic
# Out:
# Out[43]: {1: None, 2: None, 3: None, 4: None, 5: None}

# %%
lista
# Out:
# Out[44]: [10, 20, 30, 40, 50]

# %%
dic[1]=lista[0]
dic[2]=lista[1]
dic[3]=lista[2]
dic[4]=lista[3]
dic[5]=lista[4]

# %%
dic
# Out:
# Out[46]: {1: 10, 2: 20, 3: 30, 4: 40, 5: 50}
